# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn  as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
data=pd.read_csv("general_data.csv")
data.head()
labelencoder=LabelEncoder()
data["Attrition"]=labelencoder.fit_transform(data["Attrition"])

# %%
x=data["EmployeeCount"]

# %%
data["BusinessTravel"]=labelencoder.fit_transform(data["BusinessTravel"])
data["Gender"]=labelencoder.fit_transform(data["Gender"])
data["Department"]=labelencoder.fit_transform(data["Department"])
data["EducationField"]=labelencoder.fit_transform(data["EducationField"])
data["MaritalStatus"]=labelencoder.fit_transform(data["MaritalStatus"])
data["EducationField"]=labelencoder.fit_transform(data["EducationField"])
data["JobRole"]=labelencoder.fit_transform(data["JobRole"])
data["Over18"]=labelencoder.fit_transform(data["Over18"])
data.head()
data.describe()
data.corr()
data.columns
#data.info()
data1=data.drop(["TotalWorkingYears","Over18","StandardHours","EmployeeCount","EmployeeID"],axis=1)
data1.head()
data1.isna().sum()
data1["NumCompaniesWorked"]=np.where(data1["NumCompaniesWorked"].isnull(),int(data1["NumCompaniesWorked"].mean()),data1["NumCompaniesWorked"])

# %%
data1["NumCompaniesWorked"].isna().sum()
# Out:
# 0

# %%
data1.corr()
# Out:
#                               Age  Attrition  BusinessTravel  Department  \
# Age                      1.000000  -0.159205        0.024751   -0.010846
# Attrition               -0.159205   1.000000        0.000074   -0.048206
# BusinessTravel           0.024751   0.000074        1.000000   -0.010982
# Department              -0.010846  -0.048206       -0.010982    1.000000
# DistanceFromHome         0.006963  -0.009730        0.024616    0.012134
# Education               -0.035706  -0.015111        0.002755   -0.004597
# EducationField           0.043194  -0.057940       -0.015462    0.013720
# Gender                  -0.039352   0.018125       -0.039243    0.003158
# JobLevel                -0.002884  -0.010290        0.046111    0.002923
# JobRole                  0.011422   0.025809       -0.027194   -0.025466
# MaritalStatus           -0.095029   0.162070        0.024001   -0.044619
# MonthlyIncome           -0.044314  -0.031176       -0.037597   -0.032237
# ...

# %%
#sns.pairplot(data1)

# %%
data.corr()
# Out:
#                               Age  Attrition  BusinessTravel  Department  \
# Age                      1.000000  -0.159205        0.024751   -0.010846
# Attrition               -0.159205   1.000000        0.000074   -0.048206
# BusinessTravel           0.024751   0.000074        1.000000   -0.010982
# Department              -0.010846  -0.048206       -0.010982    1.000000
# DistanceFromHome         0.006963  -0.009730        0.024616    0.012134
# Education               -0.035706  -0.015111        0.002755   -0.004597
# EducationField           0.043194  -0.057940       -0.015462    0.013720
# EmployeeCount                 NaN        NaN             NaN         NaN
# EmployeeID               0.008649  -0.004729       -0.002590   -0.003455
# Gender                  -0.039352   0.018125       -0.039243    0.003158
# JobLevel                -0.002884  -0.010290        0.046111    0.002923
# JobRole                  0.011422   0.025809       -0.027194   -0.025466
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
features=data[["Education","Age",'YearsSinceLastPromotion',"PercentSalaryHike",'YearsAtCompany']]
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(features, data["Attrition"], test_size=0.33)

# %%
from sklearn.linear_model import LogisticRegression 
classifier = LogisticRegression(random_state = 0) 
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=0, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
ypred=classifier.predict(X_test)

# %%
classifier.score(X_)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-b5bf584e92f0> in <module>
# ----> 1 classifier.score()
#
# TypeError: score() missing 2 required positional arguments: 'X' and 'y'

# %%
ypred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, ypred)
cnf_matrix
# Out:
# array([[1220,    0],
#        [ 236,    0]], dtype=int64)
